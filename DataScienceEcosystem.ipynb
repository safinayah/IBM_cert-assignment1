# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# Data science combines domain expertise, programming skills, and knowledge of mathematics and statistics to extract meaningful insights from data. This notebook provides a concise overview of the tools and concepts that enable data-driven decision making.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool | Category | Primary Use |
# | --- | --- | --- |
# | Jupyter Notebook | Notebook | Interactive analysis |
# | RStudio | IDE | Statistical computing |
# | Apache Spark | Distributed Processing | Big data analytics |
# | Tableau | Visualization | Business intelligence |

# %% [markdown]
# ## Arithmetic Expressions Examples
# The following code cells demonstrate basic arithmetic operations commonly used when manipulating numerical data.

# %%
# Multiply and add numbers
product = 6 * 7
sum_result = product + 10

# %%
product, sum_result
# Out:
# (42, 52)

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
minutes, hours
# Out:
# (150, 2.5)

# %% [markdown]
# ## Objectives
# - Identify common tools in the data science ecosystem
# - Practice fundamental arithmetic operations in Python
# - Convert units to support time-based analyses

# %% [markdown]
# ## Author
# Ayah Safin
